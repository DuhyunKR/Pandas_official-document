# %% [markdown]
# ## Pandas Start

# %%
import pandas as pd #pandas 패키지 불러오고 pd는 pandas의 별칭
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owne Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age":[22, 35, 58],
        "Sex":["male","male","femaile"],
    }
)
df
# Out:
#                        Name  Age      Sex
# 0   Braund, Mr. Owne Harris   22     male
# 1  Allen, Mr. William Henry   35     male
# 2  Bonnell, Miss. Elizabeth   58  femaile

# %%
df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
df['Name']
# Out:
# 0     Braund, Mr. Owne Harris
# 1    Allen, Mr. William Henry
# 2    Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %%
df['Sex']
# Out:
# 0       male
# 1       male
# 2    femaile
# Name: Sex, dtype: object

# %%
ages = pd.Series([22, 35, 58], name = "Age")
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
df["Age"].max()  # max()는 DataFrame의 해당 열의 최대값 전달
# Out:
# 58

# %%
ages.max()  # max()는 Series의 최대값 전달
# Out:
# 58

# %%
df.describe() # describe() 함수는 DataFrame 테이블의 수치 데이터에 대한 기본 통계를 반환하는 함수
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000
